# %% [markdown]
# # Test PDPbox with Regression problem
# ## Kaggle Rossmann store with RandomForest regressor
# This demo is based on **Rossmann Store Sales**
# https://www.kaggle.com/c/otto-group-product-classification-challenge

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
from pdpbox import pdp, get_dataset, info_plots

# %% [markdown]
# # get dataset and model

# %%
test_ross = get_dataset.ross()
test_ross.keys()
# Out:
# dict_keys(['data', 'features', 'rf_model', 'target'])

# %%
ross_data = test_ross['data']
ross_features = test_ross['features']
ross_model = test_ross['rf_model']
ross_target = test_ross['target']

# %%
ross_model
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=4,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# # 1. Binary feature: SchoolHoliday

# %% [markdown]
# ## 1.1 target distribution through feature 'SchoolHoliday'

# %%
fig, axes, summary_df = info_plots.target_plot(
    df=ross_data, feature='SchoolHoliday', feature_name='SchoolHoliday', target=ross_target
)
_ = axes['bar_ax'].set_xticklabels(['Not SchoolHoliday', 'SchoolHoliday'])

# %%
summary_df
# Out:
#    x   display_column   count        Sales
# 0  0  SchoolHoliday_0  680935  6896.782411
# 1  1  SchoolHoliday_1  163457  7200.181650

# %% [markdown]
# ## 1.2 check prediction distribution through feature 'SchoolHoliday'

# %%
fig, axes, summary_df = info_plots.actual_plot(
    model=ross_model, X=ross_data[ross_features], feature='SchoolHoliday', feature_name='SchoolHoliday'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-29a2fcdfd757> in <module>
#       1 fig, axes, summary_df = info_plots.actual_plot(
# ----> 2     model=ross_model, X=ross_data[ross_features], feature='SchoolHoliday', feature_name='SchoolHoliday'
#       3 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pdpbox\info_plots.py in actual_plot(model, X, feature, feature_name, num_grid_points, grid_type, percentile_range, grid_range, cust_grid_points, show_percentile, show_outliers, endpoint, which_classes, predict_kwds, ncols, figsize, plot_params)
#     289     # make predictions
#     290     # info_df only contains feature value and actual predictions
# --> 291     prediction = predict(X, **predict_kwds)
#     292     info_df = X[_make_list(feature)]
#     293     actual_prediction_columns = ['actual_prediction']
#
# TypeError: predict() argument after ** must be a mapping, not NoneType

# %%
summary_df
# Out:
#    x   display_column   count        Sales
# 0  0  SchoolHoliday_0  680935  6896.782411
# 1  1  SchoolHoliday_1  163457  7200.181650

# %% [markdown]
# ## 1.3 pdp for feature 'SchoolHoliday'

# %%
pdp_SchoolHoliday = pdp.pdp_isolate(
    model=ross_model, dataset=ross_data, model_features=ross_features, feature='SchoolHoliday'
)
fig, axes = pdp.pdp_plot(pdp_SchoolHoliday, 'SchoolHoliday', plot_lines=True, frac_to_plot=100)

# %%
fig, axes = pdp.pdp_plot(pdp_SchoolHoliday, 'SchoolHoliday', plot_lines=True, frac_to_plot=100, plot_pts_dist=True)

# %% [markdown]
# # 2. one-hot encoding feature: StoreType

# %% [markdown]
# ## 2.1 target distribution through feature 'StoreType'

# %%
fig, axes, summary_df = info_plots.target_plot(
    df=ross_data, feature=['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d'], 
    feature_name='StoreType', target=ross_target
)

# %%
summary_df
# Out:
#    x display_column   count         Sales
# 0  0    StoreType_a  457077   6925.167661
# 1  1    StoreType_b   15563  10231.407505
# 2  2    StoreType_c  112978   6932.512755
# 3  3    StoreType_d  258774   6822.141881

# %% [markdown]
# ## 2.2 check prediction distribution through feature 'StoreType'

# %%
fig, axes, summary_df = info_plots.actual_plot(
    model=ross_model, X=ross_data[ross_features], 
    feature=['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d'], feature_name='StoreType'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-169bbc272d4a> in <module>
#       1 fig, axes, summary_df = info_plots.actual_plot(
#       2     model=ross_model, X=ross_data[ross_features],
# ----> 3     feature=['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d'], feature_name='StoreType'
#       4 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pdpbox\info_plots.py in actual_plot(model, X, feature, feature_name, num_grid_points, grid_type, percentile_range, grid_range, cust_grid_points, show_percentile, show_outliers, endpoint, which_classes, predict_kwds, ncols, figsize, plot_params)
#     289     # make predictions
#     290     # info_df only contains feature value and actual predictions
# --> 291     prediction = predict(X, **predict_kwds)
#     292     info_df = X[_make_list(feature)]
#     293     actual_prediction_columns = ['actual_prediction']
#
# TypeError: predict() argument after ** must be a mapping, not NoneType

# %%
summary_df
# Out:
#    x display_column   count         Sales
# 0  0    StoreType_a  457077   6925.167661
# 1  1    StoreType_b   15563  10231.407505
# 2  2    StoreType_c  112978   6932.512755
# 3  3    StoreType_d  258774   6822.141881

# %% [markdown]
# ## 2.3 pdp for feature 'StoreType'

# %%
# %%time
pdp_StoreType = pdp.pdp_isolate(
    model=ross_model, dataset=ross_data, model_features=ross_features, 
    feature=['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d']
)
fig, axes = pdp.pdp_plot(pdp_StoreType, 'StoreType', plot_lines=True, frac_to_plot=100)
# Out:
# Wall time: 7.84 s

# %%
fig, axes = pdp.pdp_plot(pdp_StoreType, 'StoreType', plot_lines=True, frac_to_plot=100, plot_pts_dist=True)

# %% [markdown]
# # 3. numeric feature: weekofyear

# %% [markdown]
# ## 3.1 target distribution through feature 'weekofyear'

# %%
fig, axes, summary_df = info_plots.target_plot(
    df=ross_data, feature='weekofyear', feature_name='weekofyear', target=ross_target, show_percentile=True
)

# %%
summary_df
# Out:
#    x display_column  value_lower  value_upper percentile_column  \
# 0  0         [1, 5)          1.0          5.0        [0, 11.11)
# 1  1        [5, 10)          5.0         10.0    [11.11, 22.22)
# 2  2       [10, 15)         10.0         15.0    [22.22, 33.33)
# 3  3       [15, 20)         15.0         20.0    [33.33, 44.44)
# 4  4       [20, 25)         20.0         25.0    [44.44, 55.56)
# 5  5       [25, 30)         25.0         30.0    [55.56, 66.67)
# 6  6       [30, 37)         30.0         37.0    [66.67, 77.78)
# 7  7       [37, 45)         37.0         45.0    [77.78, 88.89)
# 8  8       [45, 52]         45.0         52.0      [88.89, 100]
#
#    percentile_lower  percentile_upper   count        Sales
# 0              0.00             11.11   74699  6611.900307
# 1             11.11             22.22  100320  6548.074412
# 2             22.22             33.33   97183  7047.416801
# 3             33.33             44.44   93010  7150.762251
# 4             44.44             55.56   93887  6912.765740
# 5             55.56             66.67   96837  7018.025414
# 6             66.67             77.78   98408  6713.488893
# 7             77.78             88.89   95524  6580.778694
# 8             88.89            100.00   94524  7981.965109

# %% [markdown]
# ## 3.2 check prediction distribution through feature 'weekofyear'

# %%
fig, axes, summary_df = info_plots.actual_plot(
    model=ross_model, X=ross_data[ross_features], feature='weekofyear', feature_name='weekofyear', 
    show_percentile=True
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-f400d9ba62a2> in <module>
#       1 fig, axes, summary_df = info_plots.actual_plot(
#       2     model=ross_model, X=ross_data[ross_features], feature='weekofyear', feature_name='weekofyear',
# ----> 3     show_percentile=True
#       4 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pdpbox\info_plots.py in actual_plot(model, X, feature, feature_name, num_grid_points, grid_type, percentile_range, grid_range, cust_grid_points, show_percentile, show_outliers, endpoint, which_classes, predict_kwds, ncols, figsize, plot_params)
#     289     # make predictions
#     290     # info_df only contains feature value and actual predictions
# --> 291     prediction = predict(X, **predict_kwds)
#     292     info_df = X[_make_list(feature)]
#     293     actual_prediction_columns = ['actual_prediction']
#
# TypeError: predict() argument after ** must be a mapping, not NoneType

# %%
summary_df
# Out:
#    x display_column  value_lower  value_upper percentile_column  \
# 0  0         [1, 5)          1.0          5.0        [0, 11.11)
# 1  1        [5, 10)          5.0         10.0    [11.11, 22.22)
# 2  2       [10, 15)         10.0         15.0    [22.22, 33.33)
# 3  3       [15, 20)         15.0         20.0    [33.33, 44.44)
# 4  4       [20, 25)         20.0         25.0    [44.44, 55.56)
# 5  5       [25, 30)         25.0         30.0    [55.56, 66.67)
# 6  6       [30, 37)         30.0         37.0    [66.67, 77.78)
# 7  7       [37, 45)         37.0         45.0    [77.78, 88.89)
# 8  8       [45, 52]         45.0         52.0      [88.89, 100]
#
#    percentile_lower  percentile_upper   count        Sales
# 0              0.00             11.11   74699  6611.900307
# 1             11.11             22.22  100320  6548.074412
# 2             22.22             33.33   97183  7047.416801
# 3             33.33             44.44   93010  7150.762251
# 4             44.44             55.56   93887  6912.765740
# 5             55.56             66.67   96837  7018.025414
# 6             66.67             77.78   98408  6713.488893
# 7             77.78             88.89   95524  6580.778694
# 8             88.89            100.00   94524  7981.965109

# %% [markdown]
# ## 3.3 pdp for feature 'weekofyear'

# %%
pdp_weekofyear = pdp.pdp_isolate(
    model=ross_model, dataset=ross_data, model_features=ross_features, feature='weekofyear'
)
fig, axes = pdp.pdp_plot(pdp_weekofyear, 'weekofyear')

# %%
fig, axes = pdp.pdp_plot(
    pdp_weekofyear, 'weekofyear', plot_lines=True, frac_to_plot=100, x_quantile=True, 
    plot_pts_dist=True, show_percentile=True
)

# %% [markdown]
# # 4. Interaction between two variables: weekofyear and StoreType

# %% [markdown]
# ## 4.1 target distribution through feature combination of 'weekofyear' and 'StoreType'

# %%
fig, axes, summary_df = info_plots.target_plot_interact(
    df=ross_data, features=['weekofyear', ['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d']], 
    feature_names=['weekofyear', 'StoreType'], target=ross_target
)

# %%
summary_df.head()
# Out:
#    x1  x2 display_column_1 display_column_2  value_lower_1  value_upper_1  \
# 0   0   0           [1, 5)      StoreType_a            1.0            5.0
# 1   0   1           [1, 5)      StoreType_b            1.0            5.0
# 2   0   2           [1, 5)      StoreType_c            1.0            5.0
# 3   0   3           [1, 5)      StoreType_d            1.0            5.0
# 4   1   0          [5, 10)      StoreType_a            5.0           10.0
#
#    count        Sales
# 0  40316  6569.986060
# 1   1368  9288.116959
# 2   9866  6637.681026
# 3  23149  6515.757830
# 4  54066  6538.169718

# %% [markdown]
# ## 4.2 prediction distribution through feature combination of 'weekofyear' and 'StoreType'

# %%
fig, axes, summary_df = info_plots.actual_plot_interact(
    model=ross_model, X=ross_data[ross_features], 
    features=['weekofyear', ['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d']], 
    feature_names=['weekofyear', 'StoreType']
)

# %%
summary_df.head()
# Out:
#    x1  x2 display_column_1 display_column_2  value_lower_1  value_upper_1  \
# 0   0   0           [1, 5)      StoreType_a            1.0            5.0
# 1   0   1           [1, 5)      StoreType_b            1.0            5.0
# 2   0   2           [1, 5)      StoreType_c            1.0            5.0
# 3   0   3           [1, 5)      StoreType_d            1.0            5.0
# 4   1   0          [5, 10)      StoreType_a            5.0           10.0
#
#    count  actual_prediction_q1  actual_prediction_q2  actual_prediction_q3
# 0  40316           5764.438163           6442.763004           7293.834595
# 1   1368           7424.239747           8519.579900          10686.352088
# 2   9866           6087.560179           6440.314179           6952.554776
# 3  23149           5828.575845           6352.022564           6822.044315
# 4  54066           5559.703968           6258.869377           7158.502533

# %% [markdown]
# ## 4.3 pdp for feature combination of 'weekofyear' and 'StoreType'

# %%
# %%time
inter_rf = pdp.pdp_interact(
    model=ross_model, dataset=ross_data, model_features=ross_features, 
    features=['weekofyear', ['StoreType_a', 'StoreType_b', 'StoreType_c', 'StoreType_d']]
)
# Out:
# Wall time: 1min 57s

# %%
fig, axes = pdp.pdp_interact_plot(
    inter_rf, ['weekofyear', 'StoreType'], x_quantile=True, plot_type='contour', plot_pdp=False
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-1192b372f80e> in <module>
#       1 fig, axes = pdp.pdp_interact_plot(
# ----> 2     inter_rf, ['weekofyear', 'StoreType'], x_quantile=True, plot_type='contour', plot_pdp=False
#       3 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pdpbox\pdp.py in pdp_interact_plot(pdp_interact_out, feature_names, plot_type, x_quantile, plot_pdp, which_classes, figsize, ncols, plot_params)
#     773             fig.add_subplot(inter_ax)
#     774             _pdp_inter_one(pdp_interact_out=pdp_interact_plot_data[0], inter_ax=inter_ax, norm=None,
# --> 775                            feature_names=feature_names_adj, **inter_params)
#     776     else:
#     777         wspace = 0.3
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pdpbox\pdp_plot_utils.py in _pdp_inter_one(pdp_interact_out, feature_names, plot_type, inter_ax, x_quantile, plot_params, norm, ticks)
#     330             # for numeric not quantile
#     331             X, Y = np.meshgrid(pdp_interact_out.feature_grids[0], pdp_interact_out.feature_grids[1])
# --> 332         im = _pdp_contour_plot(X=X, Y=Y, **inter_params)
#     333     elif plot_type == 'grid':
#     334         im = _pdp_inter_grid(**inter_params)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pdpbox\pdp_plot_utils.py in _pdp_contour_plot(X, Y, pdp_mx, inter_ax, cmap, norm, inter_fill_alpha, fontsize, plot_params)
#     249     c1 = inter_ax.contourf(X, Y, pdp_mx, N=level, origin='lower', cmap=cmap, norm=norm, alpha=inter_fill_alpha)
#     250     c2 = inter_ax.contour(c1, levels=c1.levels, colors=contour_color, origin='lower')
# --> 251     inter_ax.clabel(c2, contour_label_fontsize=fontsize, inline=1)
#     252     inter_ax.set_aspect('auto')
#     253
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in clabel(self, CS, *args, **kwargs)
#    6243
#    6244     def clabel(self, CS, *args, **kwargs):
# -> 6245         return CS.clabel(*args, **kwargs)
#    6246     clabel.__doc__ = mcontour.ContourSet.clabel.__doc__
#    6247
#
# TypeError: clabel() got an unexpected keyword argument 'contour_label_fontsize'

# %%
fig, axes = pdp.pdp_interact_plot(
    inter_rf, ['weekofyear', 'StoreType'], x_quantile=True, plot_type='contour', plot_pdp=True
)

# %%
fig, axes = pdp.pdp_interact_plot(
    inter_rf, ['weekofyear', 'StoreType'], x_quantile=True, plot_type='grid', plot_pdp=True
)
